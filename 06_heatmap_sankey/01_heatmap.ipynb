# %% [markdown]
# <a href="https://colab.research.google.com/github/cristianmejia00/clustering/blob/main/Topic_Models_using_BERTopic_HEATMAPS_v1_20241018.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Heatmap for Topic Modeling with BERTopic

# %% [markdown]
# # Requirements

# %% [markdown]
# ## Packages installation and initialization

# %%
# !pip install bertopic[visualization]
# Out:
# Collecting bertopic[visualization]
#   Downloading bertopic-0.16.4-py3-none-any.whl.metadata (23 kB)
# WARNING: bertopic 0.16.4 does not provide the extra 'visualization'
# Collecting hdbscan>=0.8.29 (from bertopic[visualization])
#   Downloading hdbscan-0.8.39-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (15 kB)
# Requirement already satisfied: numpy>=1.20.0 in /usr/local/lib/python3.10/dist-packages (from bertopic[visualization]) (1.26.4)
# Requirement already satisfied: pandas>=1.1.5 in /usr/local/lib/python3.10/dist-packages (from bertopic[visualization]) (2.2.2)
# Requirement already satisfied: plotly>=4.7.0 in /usr/local/lib/python3.10/dist-packages (from bertopic[visualization]) (5.24.1)
# Requirement already satisfied: scikit-learn>=0.22.2.post1 in /usr/local/lib/python3.10/dist-packages (from bertopic[visualization]) (1.5.2)
# Requirement already satisfied: sentence-transformers>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from bertopic[visualization]) (3.2.1)
# Requirement already satisfied: tqdm>=4.41.1 in /usr/local/lib/python3.10/dist-packages (from bertopic[visualization]) (4.66.6)
# Collecting umap-learn>=0.5.0 (from bertopic[visualization])
#   Downloading umap_learn-0.5.7-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: scipy>=1.0 in /usr/local/lib/python3.10/dist-packages (from hdbscan>=0.8.29->bertopic[visualization]) (1.13.1)
# Requirement already satisfied: joblib>=1.0 in /usr/local/lib/python3.10/dist-packages (from hdbscan>=0.8.29->bertopic[visualization]) (1.4.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.5->bertopic[visualization]) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.5->bertopic[visualization]) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.5->bertopic[visualization]) (2024.2)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly>=4.7.0->bertopic[visualization]) (9.0.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from plotly>=4.7.0->bertopic[visualization]) (24.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.22.2.post1->bertopic[visualization]) (3.5.0)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=0.4.1->bertopic[visualization]) (4.44.2)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=0.4.1->bertopic[visualization]) (2.5.0+cu121)
# Requirement already satisfied: huggingface-hub>=0.20.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=0.4.1->bertopic[visualization]) (0.24.7)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=0.4.1->bertopic[visualization]) (10.4.0)
# Requirement already satisfied: numba>=0.51.2 in /usr/local/lib/python3.10/dist-packages (from umap-learn>=0.5.0->bertopic[visualization]) (0.60.0)
# Collecting pynndescent>=0.5 (from umap-learn>=0.5.0->bertopic[visualization])
#   Downloading pynndescent-0.5.13-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic[visualization]) (3.16.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic[visualization]) (2024.10.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic[visualization]) (6.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic[visualization]) (2.32.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic[visualization]) (4.12.2)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba>=0.51.2->umap-learn>=0.5.0->bertopic[visualization]) (0.43.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas>=1.1.5->bertopic[visualization]) (1.16.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic[visualization]) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic[visualization]) (3.1.4)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic[visualization]) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch>=1.11.0->sentence-transformers>=0.4.1->bertopic[visualization]) (1.3.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers>=0.4.1->bertopic[visualization]) (2024.9.11)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers>=0.4.1->bertopic[visualization]) (0.4.5)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers>=0.4.1->bertopic[visualization]) (0.19.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.11.0->sentence-transformers>=0.4.1->bertopic[visualization]) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic[visualization]) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic[visualization]) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic[visualization]) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic[visualization]) (2024.8.30)
# Downloading hdbscan-0.8.39-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 13.2 MB/s eta 0:00:00
# Downloading umap_learn-0.5.7-py3-none-any.whl (88 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.8/88.8 kB 5.8 MB/s eta 0:00:00
# Downloading bertopic-0.16.4-py3-none-any.whl (143 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.7/143.7 kB 8.3 MB/s eta 0:00:00
# Downloading pynndescent-0.5.13-py3-none-any.whl (56 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.9/56.9 kB 2.2 MB/s eta 0:00:00
# Installing collected packages: pynndescent, hdbscan, umap-learn, bertopic
# Successfully installed bertopic-0.16.4 hdbscan-0.8.39 pynndescent-0.5.13 umap-learn-0.5.7

# %%
import pandas as pd
import time
import math
from datetime import date
import uuid
import re
import os
import json
import pickle
from itertools import compress
from bertopic import BERTopic
from umap import UMAP
from gensim.parsing.preprocessing import remove_stopwords
import numpy as np
from sklearn.cluster import KMeans

# %%
# Change to the name of the folder in your Google Drive
root_folder_name = 'Bibliometrics_Drive'
ROOT_FOLDER_PATH = f"drive/MyDrive/{root_folder_name}"

# %% [markdown]
# ## Connect your Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Function to save object to a pickle file
def save_object_as_pickle(obj, filename):
  """
  Saves an object as a pickle file.

  Args:
      obj: The object to be saved.
      filename: The filename of the pickle file.
  """
  with open(filename, "wb") as f:
    pickle.dump(obj, f)

# %%
# Function to load pickle object given a path
def load_pickle(path):
    with open(path, 'rb') as f:
        return pickle.load(f)

# %%
def save_heatmap_settings_as_json(heatmap_settings, filename="heatmap_settings.json"):
  """Saves heatmap settings as a JSON file with pretty indentation.

  Args:
      heatmap_settings: The heatmap settings dictionary.
      filename: The name of the JSON file.
  """
  with open(filename, "w") as f:
    json.dump(heatmap_settings, f, indent=4)

# %% [markdown]
# ---

# %% [markdown]
# ## PART 3: Merging Topic Models

# %% [markdown]
# # 🔴 Input files and options

# %%
heatmap_settings = {
    'metadata': {
      'heatmap_analysis_id': 'H004',
      'heatmap_name': 'PIK_RIKEN_UTOKYO',
      'date': '2024-11-02',
      'created_by': 'cristianmejia00@gmail.com',
      'notes': '',
      'input_directory': '',
      'output_directory': ''
    },
    'global': {
                'min_cluster_size': 10,
                'seed': 100,
                'transformer_model': 'all-MiniLM-L6-v2',
                'sankey_threshold': 0.8
              },
    'inputs': [
        {
            'project_folder_name': 'Q281_pik',
            'analysis_folder_name': 'a01_tm__f01_e01__km01',
            'level_folder_name': 'level0',
            'embeddings_folder_name': 'f01/e01',
            'display_name': 'PIK',
            'cluster_column': 'Cluster Code',
            'heatmap_display_order': 0,
            'sankey_display_order': 0,
            'color': "#E9571F"
        },
        {
            'project_folder_name': 'Q282c_riken_bio',
            'analysis_folder_name': 'a01_tm__f01_e01__km01',
            'embeddings_folder_name': 'f01/e01',
            'level_folder_name': 'level0',
            'display_name': 'RIKEN.Bio',
            'cluster_column': 'Cluster Code',
            'heatmap_display_order': 1,
            'sankey_display_order': 2,
            'color': '#4C962F'
        },
        {
            'project_folder_name': 'Q282a_riken_sus',
            'analysis_folder_name': 'a01_tm__f01_e01__km01',
            'embeddings_folder_name': 'f01/e01',
            'level_folder_name': 'level0',
            'display_name': 'RIKEN.Sust',
            'cluster_column': 'Cluster Code',
            'heatmap_display_order': 2,
            'sankey_display_order': 2,
            'color': '#150A9A'
        },
        {
            'project_folder_name': 'Q282b_riken_com',
            'analysis_folder_name': 'a01_tm__f01_e01__km01',
            'embeddings_folder_name': 'f01/e01',
            'level_folder_name': 'level0',
            'display_name': 'RIKEN.Com',
            'cluster_column': 'Cluster Code',
            'heatmap_display_order': 3,
            'sankey_display_order': 2,
            'color': '#808080'
        },
        {
            'project_folder_name': 'Q312_utokyo',
            'analysis_folder_name': 'a01_tm__f01_e01__km01',
            'embeddings_folder_name': 'f01/e01',
            'level_folder_name': 'level0',
            'display_name': 'UTokyo',
            'cluster_column': 'Cluster Code',
            'heatmap_display_order': 4,
            'sankey_display_order': 1,
            'color': '#F2BA05'
        }#,
        # {
        #     'project_folder_name': 'Q308_bio_plant',
        #     'analysis_folder_name': 'a01_tm__f01_e01__km01',
        #     'embeddings_folder_name': 'f01/e01',
        #     'level_folder_name': 'level0',
        #     'display_name': 'Plant',
        #     'cluster_column': 'Cluster Code',
        #     'heatmap_display_order': 4,
        #     'sankey_display_order': 1,
        #     'color': '#66FF00'
        # }
      ]
}

# %%
analysis_folder = f'{ROOT_FOLDER_PATH}/{heatmap_settings["metadata"]["heatmap_analysis_id"]}'

if not os.path.exists(analysis_folder):
  # !mkdir $analysis_folder


# Save settings
save_heatmap_settings_as_json(heatmap_settings, filename=f'{ROOT_FOLDER_PATH}/{heatmap_settings["metadata"]["heatmap_analysis_id"]}/heatmap_settings_{heatmap_settings["metadata"]["heatmap_analysis_id"]}_{heatmap_settings["metadata"]["heatmap_name"]}.json')

# %%
heatmap_input_dfs = []
for tm in heatmap_settings['inputs']:
  document_path = f'{ROOT_FOLDER_PATH}/{tm["project_folder_name"]}/{tm["analysis_folder_name"]}/{tm["level_folder_name"]}/article_report.csv'
  print(document_path)
  input_df = pd.read_csv(document_path,
                         usecols=['ID', 'uuid', tm['cluster_column']])
  # Each dataset can use different clustering result e.g. X_C, level0, level1, so we need to unify the header name for concatenation
  input_df['display_name'] = tm['display_name']
  input_df['cluster'] = input_df['display_name'] + "-" + input_df[tm['cluster_column']].astype(str)
  input_df = input_df.rename(columns={'ID': 'UT'})
  input_df = input_df.drop(columns=[tm['cluster_column']])
  heatmap_input_dfs.append(input_df)
# Out:
# drive/MyDrive/Bibliometrics_Drive/Q281_pik/a01_tm__f01_e01__km01/level0/article_report.csv
# drive/MyDrive/Bibliometrics_Drive/Q282c_riken_bio/a01_tm__f01_e01__km01/level0/article_report.csv
# drive/MyDrive/Bibliometrics_Drive/Q282a_riken_sus/a01_tm__f01_e01__km01/level0/article_report.csv
# drive/MyDrive/Bibliometrics_Drive/Q282b_riken_com/a01_tm__f01_e01__km01/level0/article_report.csv
# drive/MyDrive/Bibliometrics_Drive/Q312_utokyo/a01_tm__f01_e01__km01/level0/article_report.csv

# %%
document_info = pd.concat(heatmap_input_dfs).reset_index(drop=True)
print(len(document_info))
document_info.head()
# Out:
# 24590
#                     UT                                  uuid display_name  \
# 0  WOS:000071415800010  4bf5613f-f5fb-4a9f-8f5c-466f12e33461          PIK
# 1  WOS:000071604200043  0d733506-e76b-4a01-9408-411d8714c8b2          PIK
# 2  WOS:000071740800015  d2c2a60c-e484-42b3-8839-f8fdb7d8dafd          PIK
# 3  WOS:000072198600007  78239207-c2b0-4ec2-935e-feb73f5f2884          PIK
# 4  WOS:000072339800002  c68a089b-5260-42ec-8623-03a3cd829f83          PIK
#
#   cluster
# 0  PIK-20
# 1   PIK-9
# 2  PIK-29
# 3  PIK-27
# 4  PIK-14

# %% [markdown]
# ---

# %% [markdown]
# ## PART 5. Heatmap

# %%
# For firms we know, simply get the embeddings back.
embeddings_list = []
corpus_list = []
for tm in heatmap_settings['inputs']:
  print(f"=================Loading: {tm['project_folder_name']}")
  embeddings = load_pickle(f"{ROOT_FOLDER_PATH}/{tm['project_folder_name']}/{tm['embeddings_folder_name']}/embeddings.pck")
  if type(embeddings) == dict:
    print('Dict type found')
    embeddings = embeddings['embeddings']
  corpus_tmp = pd.read_csv(f"{ROOT_FOLDER_PATH}/{tm['project_folder_name']}/{tm['embeddings_folder_name']}/corpus.csv")

  embeddings_list.append(embeddings)
  corpus_list.append(corpus_tmp)
# Out:
# =================Loading: Q281_pik
# =================Loading: Q282c_riken_bio
# =================Loading: Q282a_riken_sus
# =================Loading: Q282b_riken_com
# =================Loading: Q312_utokyo
# Dict type found

# %%
# Combine embeddings
embeddings_uploaded = np.vstack(embeddings_list)
corpus_uploaded = pd.concat(corpus_list).reset_index(drop=True)

# %%
embeddings_uploaded.shape
# Out:
# (24730, 384)

# %%
print(len(embeddings_uploaded))
print(len(corpus_uploaded))
print(len(document_info))
# Out:
# 24730
# 24730
# 24590

# %%
# prompt: add `embeddings_uploaded` as a column to `corpus_uploaded`
corpus_uploaded['embeddings'] = list(embeddings_uploaded)

# %%
# prompt: remove  rows of corpus_uploaded where UT is duplicated

# Remove rows where 'UT' is duplicated, keeping the first occurrence
corpus_uploaded = corpus_uploaded.drop_duplicates(subset=['UT'], keep='first')

# %%
# prompt: merge `corpus_uploaded` and `document_info` by column UT. The merged data frame has as many rows and same sorting as corpus_uploaded. The merged data frame is named `full_corpus`.
full_corpus = pd.merge(document_info[['UT', 'uuid', 'cluster']], corpus_uploaded[['UT', 'text', 'embeddings']], on='UT', how='left')

# %%
len(full_corpus)
# Out:
# 24590

# %%
len(document_info)
# Out:
# 24590

# %%
# prompt: Remove all rows in full_corpus where the size of column `embeddings` do not match 384
full_corpus = full_corpus[full_corpus['embeddings'].apply(lambda x: len(x) == 384 if isinstance(x, list) or isinstance(x, np.ndarray) else False)]

# %%
len(full_corpus)
# Out:
# 24590

# %%
# Remodel the topic model
from bertopic.backend import BaseEmbedder
from bertopic.cluster import BaseCluster
from bertopic.vectorizers import ClassTfidfTransformer
from bertopic.dimensionality import BaseDimensionalityReduction
from sentence_transformers import SentenceTransformer

# %%
cluster_idx_mapping = full_corpus.cluster.value_counts()
cluster_idx_mapping = cluster_idx_mapping[cluster_idx_mapping >= heatmap_settings['global']['min_cluster_size']]
cluster_idx_mapping
# Out:
# cluster
# RIKEN.Sust-1     374
# PIK-1            318
# PIK-2            317
# UTokyo-0         279
# PIK-3            269
#                 ...
# RIKEN.Sust-30     13
# RIKEN.Bio-20      12
# RIKEN.Bio-21      11
# RIKEN.Bio-22      11
# RIKEN.Bio-23      10
# Name: count, Length: 236, dtype: int64

# %%
full_corpus = full_corpus[full_corpus.cluster.isin(cluster_idx_mapping.index.to_list())]

# %%
len(full_corpus)
# Out:
# 24590

# %%
# Form the embbedings
my_embeddings = np.vstack(full_corpus['embeddings'].tolist())

# %%
# get text and topics
docs = full_corpus.text
cluster_list = full_corpus.cluster

# %%
idx_cluster = [cluster_idx_mapping.index.get_loc(i) for i in cluster_list]

# %%
len(idx_cluster) == len(docs) == len(my_embeddings)
# Out:
# True

# %% [markdown]
# # 🟢🟢

# %%
# Init "empty" models
embedding_model = SentenceTransformer(heatmap_settings["global"]["transformer_model"])
empty_dimensionality_model = BaseDimensionalityReduction()
empty_cluster_model = BaseCluster()
ctfidf_model = ClassTfidfTransformer(reduce_frequent_words=True)

# Fit BERTopic without actually performing any clustering
topic_model= BERTopic(
        embedding_model=embedding_model,
        umap_model=empty_dimensionality_model,
        hdbscan_model=empty_cluster_model,
        ctfidf_model=ctfidf_model
)

# %%
topics, probs = topic_model.fit_transform(docs, my_embeddings, y=idx_cluster)

# %%
tm_summary = topic_model.get_topic_info()
tm_summary
# Out:
#      Topic  Count                                         Name  \
# 0        0    374        0_catalyst_catalyzed_scandium_alkenes
# 1        1    318  1_oscillators_synchronization_delay_chimera
# 2        2    317          2_vegetation_amazon_npp_terrestrial
# 3        3    279           3_magnetic_spin_hall_magnetization
# 4        4    269        4_hydrological_river_runoff_catchment
# ..     ...    ...                                          ...
# 231    231     13               231_sg1_inkt_endothelin_traj18
# 232    232     12           232_gibberellin_atgid1a_atgid1c_ga
# 233    233     11       233_petal_erectile_abscission_aquatica
# 234    234     11                234_1928_nakase_komagata_yana
# 235    235     10              235_pale_albino_prototheca_apg1
#
#                                         Representation  \
# 0    [catalyst, catalyzed, scandium, alkenes, catal...
# 1    [oscillators, synchronization, delay, chimera,...
# 2    [vegetation, amazon, npp, terrestrial, albedo,...
# 3    [magnetic, spin, hall, magnetization, ferromag...
# 4    [hydrological, river, runoff, catchment, basin...
# ..                                                 ...
# 231  [sg1, inkt, endothelin, traj18, granulosum, st...
# 232  [gibberellin, atgid1a, atgid1c, ga, atgid1b, s...
# 233  [petal, erectile, abscission, aquatica, pub4, ...
# 234  [1928, nakase, komagata, yana, banno, zsolt, f...
# 235  [pale, albino, prototheca, apg1, kdelr1, isr, ...
#
#                                    Representative_Docs
# 0    [scandium-catalyzed syndiospecific polymerizat...
# 1    [effect fractional derivatives amplitude chime...
# 2    [climate extreme versus carbon extreme: respon...
# 3    [fabrication single-crystalline yfeo<sub>3</su...
# 4    [propagation forcing model uncertainties hydro...
# ..                                                 ...
# 231  [super-sensitive auxin-inducible degron engine...
# 232  [overview gibberellin metabolism enzyme genes ...
# 233  [plant u-box protein, pub4, regulates asymmetr...
# 234  [kockovaella nakase, banno & y. yamada (1991) ...
# 235  [multiple losses photosynthesis convergent red...
#
# [236 rows x 5 columns]

# %%
# Document information. Including the topic assignation
test = topic_model.get_document_info(docs, df = full_corpus)
test = test[['cluster', 'Name']].drop_duplicates(subset=['cluster'], keep='first')
print(test.shape)
test.head(10)
# Out:
# (236, 2)
#    cluster                                        Name
# 0   PIK-20              61_monsoon_zonal_arctic_indian
# 1    PIK-9                15_glacial_cave_kyr_holocene
# 2   PIK-29            126_nan_editorial_crutzen_things
# 3   PIK-27  124_extinction_permafrost_sahara_biosphere
# 4   PIK-14               29_forest_forests_stand_bison
# 5    PIK-2         2_vegetation_amazon_npp_terrestrial
# 6   PIK-17   42_sdgs_nexus_sustainability_biodiversity
# 8    PIK-3       4_hydrological_river_runoff_catchment
# 10   PIK-4           5_paris_mitigation_emissions_ndcs
# 11  PIK-13   26_coastal_precipitation_downscaling_cclm

# %% [markdown]
# ---

# %%
# Default
# Visualize topic similarity using heatmap (self similarity)
hm = topic_model.visualize_heatmap()
#hm.write_html(f"{ROOT_FOLDER_PATH}/heatmap_updated.html")
hm
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="ba9a1c86-49f7-42a4-88cf-141397e2fbdb" class="plotly-graph-div" style="height:800px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ba9a1c86-49f7-42a4-88cf-141397e2fbdb")) {                    Plotly.newPlot(                        "ba9a1c86-49f7-42a4-88cf-141397e2fbdb",                        [{"coloraxis":"coloraxis","name":"0","x":["0_catalyst_catalyzed_scandium","1_oscillators_synchronizati...","2_vegetation_amazon_npp","3_magnetic_spin_hall","4_hydrological_river_runoff","5_paris_mitigation_emissions","6_nan_reply_preface","7_galaxies_galaxy_star","8_embryos_germ_oocytes","9_electricity_coal_renewable","10_tumor_canine_aml","11_ice_sheet_amoc","12_aba_drought_abscisic","13_usepackage_document_alge...","14_food_farmers_meat","15_glacial_cave_kyr","16_qcd_quark_lattice","17_pathogen_immunity_collet...","18_coronary_artery_atrial","19_nino_rainfall_el","20_pluripotent_stem_es","21_jcm_lactobacillus_nov","22_tax_eu_pricing","23_auxin_iaa_xylem","24_adaptation_ipcc_assessment","25_polyketide_biosynthetic_...","26_coastal_precipitation_do...","27_ttx_volvox_insects","28_mental_psychological_dis...","29_forest_forests_stand","30_crop_maize_yield","31_object_semantic_segmenta...","32_jdp2_jun_adenovirus","33_impulsive_consensus_grids","34_urban_logistics_visitors","35_ligands_complexes_reacti...","36_dst_rbp4_shh","37_silk_3hb_spider","38_landslide_ratoon_insar","39_firms_eacute_diplomacy","40_bile_mscs_liver","41_chemotherapy_colorectal_...","42_sdgs_nexus_sustainability","43_musculus_mus_subspecies","44_cov_sars_virus","45_mof_conductivity_adsorpt...","46_phonon_gan_thermoelectric","47_bleeding_biliary_endosco...","48_soc_tillage_cropland","49_motor_cortex_auditory","50_erythroid_globin_fetal","51_inhibitors_sirt2_acrolein","52_nitrate_ga_nodule","53_tempo_cellulose_gels","54_metabolomics_ms_metaboli...","55_cloud_tcs_convection","56_mantle_magma_zircon","57_gpa_superconducting_inf","58_dreb2a_dreb1a_arabidopsis","59_hubbard_spin_mott","60_recurrence_rqa_chaotic","61_monsoon_zonal_arctic","62_vulnerability_migration_...","63_earthquakes_seismic_eart...","64_epidemic_networks_spread...","65_sst_pacific_equatorial","66_micromonospora_nov_jcm","67_fish_otolith_prey","68_chloroplasts_chloroplast...","69_biosynthesis_tomatine_sga","70_hpc_file_mpi","71_alk_alectinib_lorlatinib","72_glycerol_fermentation_wax","73_conformational_md_rism","74_fruit_cassava_barley","75_fpga_fpgas_compiler","76_pain_knee_flexion","77_nov_mh1_optimum","78_senescence_muscle_skeletal","79_chloroplast_cms_kobu","80_quantum_qubit_qubits","81_care_home_health","82_gender_twitter_dysphoria","83_nucleosome_chromatin_sperm","84_mirrors_materials_cryoge...","85_neutrino_neutrinos_axion","86_diabetes_hospital_icu","87_thermoacoustic_levy_noise","88_batteries_electrolyte_el...","89_hydrogel_peg_hydrogels","90_gravitational_primordial...","91_toi_planet_disk","92_ray_pulsar_tev","93_hydropower_river_basin","94_multiplication_gpu_gpus","95_alloys_gb_cutting","96_aptamers_arrestin_trna","97_gpt_dlr_ecg","98_kidney_ckd_dialysis","99_laser_fuzz_pulse","100_bioenergy_biomass_land","101_assimilation_lightning_...","102_cry2_fmo_cry1","103_orobanchol_alkane_okeania","104_disaster_household_farm...","105_lensing_cmb_galaxy","106_topological_kondo_cooper","107_prokaryotic_microbial_cd","108_salinity_salt_tolerance","109_cfrp_ply_fiber","110_hpv_iraes_nsclc","111_estimator_wasserstein_c...","112_yeast_ache_reca","113_liver_lung_uterine","114_nuclei_skyrme_neutron","115_functionals_energies_fock","116_arthritis_il_ssc","117_eulerian_aerodynamic_re...","118_flood_floods_flooding","119_collisions_pb_alice","120_photocatalyst_photocata...","121_plasma_tokamak_plasmas","122_glasses_amorphous_therm...","123_speech_gaze ...

# %%
#pd.DataFrame(hm.data[0]['z'], columns=hm.data[0]['x']).to_csv(f'{ROOT_FOLDER_PATH}/{heatmap_settings["metadata"]["heatmap_analysis_id"]}/heatmap_matrix.csv', index=False)

# %% [markdown]
# ---

# %% [markdown]
# ## coordinates

# %%
import numpy as np
import umap

def reduce_dimensionality(data):
    # Create a UMAP object with the desired settings
    reducer = umap.UMAP(n_components=2, random_state=heatmap_settings['global']['seed'])

    # Perform dimensionality reduction
    reduced_data = reducer.fit_transform(data)

    return reduced_data

# %%
# Reduce dimensionality using UMAP
reduced_data = reduce_dimensionality(hm.data[0]['z'])
# Print the shape of the reduced data
print("Reduced data shape:", reduced_data.shape)
# Out:
# Reduced data shape: (236, 2)

# %%
dms = pd.DataFrame(reduced_data)
dms.columns = ['x', 'y']
dms['label'] = tm_summary['Name']
dms['cluster'] = dms['label'].map(test.set_index('Name')['cluster'])
dms.head()
# Out:
#           x         y                                        label  \
# 0  8.127893  1.287215        0_catalyst_catalyzed_scandium_alkenes
# 1  5.216771  3.852225  1_oscillators_synchronization_delay_chimera
# 2  2.642149  6.999850          2_vegetation_amazon_npp_terrestrial
# 3  6.546183  1.366230           3_magnetic_spin_hall_magnetization
# 4  3.019911  6.807920        4_hydrological_river_runoff_catchment
#
#         cluster
# 0  RIKEN.Sust-1
# 1         PIK-1
# 2         PIK-2
# 3      UTokyo-0
# 4         PIK-3

# %%
# Save dms
dms.to_csv(f'{ROOT_FOLDER_PATH}/{heatmap_settings["metadata"]["heatmap_analysis_id"]}/coordinates.csv', index = False)

# %%
# Save heatmap
pd.DataFrame(hm.data[0]['z'], columns=dms["cluster"]).to_csv(f'{ROOT_FOLDER_PATH}/{heatmap_settings["metadata"]["heatmap_analysis_id"]}/heatmap_matrix.csv', index=False)

# %% [markdown]
# ---

# %% [markdown]
# ## Melted

# %%
# prompt: `hm_test` is a squared matrix similarity matrix. This is a symmetric matrix so we only consider the lower triangle, without the diagonal.  Let's get the melted form as a data frame with 3 columns `Source`, `Target`, and `Similarity`. Then, sort it from the largest similarity to the lowest. Remove the pairs with value of zero.
hm_test = hm.data[0]['z']

# Assuming hm_test is your similarity matrix
df = pd.DataFrame(hm_test)

# Get the lower triangle without the diagonal
rows, cols = np.tril_indices(df.shape[0], -1)

# Create a DataFrame with Source, Target, and Similarity
similarity_df = pd.DataFrame({
    'Source': df.columns[rows],
    'Target': df.columns[cols],
    'Similarity': df.values[rows, cols]
})

# Remove rows with similarity of zero
similarity_df = similarity_df[similarity_df['Similarity'] > 0]

# Sort by similarity in descending order
similarity_df = similarity_df.sort_values('Similarity', ascending=False)

similarity_df
# Out:
#        Source  Target  Similarity
# 25212     225      12    0.969097
# 17972     190      17    0.962980
# 595        35       0    0.958142
# 5278      103      25    0.949204
# 27051     233      23    0.946157
# ...       ...     ...         ...
# 18912     194     191    0.000050
# 5634      106      69    0.000019
# 3009       78       6    0.000012
# 21622     208      94    0.000006
# 18397     192      61    0.000003
#
# [26248 rows x 3 columns]

# %%
# prompt: Using dataframe similarity_df: Replace the values of columns Source and Target with the labels from `dms["cluster"]`

# Replace Source and Target with labels from dms["cluster"]
similarity_df['Source'] = similarity_df['Source'].map(lambda x: dms["cluster"][int(x)]) # Convert x to integer
similarity_df['Target'] = similarity_df['Target'].map(lambda x: dms["cluster"][int(x)]) # Convert x to integer

# %%
similarity_df.head(100)
# Out:
#               Source        Target  Similarity
# 25212   RIKEN.Bio-16  RIKEN.Sust-2    0.969097
# 17972   RIKEN.Bio-11  RIKEN.Sust-3    0.962980
# 595         UTokyo-9  RIKEN.Sust-1    0.958142
# 5278       UTokyo-45  RIKEN.Sust-5    0.949204
# 27051   RIKEN.Bio-21  RIKEN.Sust-4    0.946157
# ...              ...           ...         ...
# 24110  RIKEN.Sust-26   RIKEN.Bio-2    0.844956
# 26331   RIKEN.Bio-18  RIKEN.Bio-16    0.844784
# 25223   RIKEN.Bio-16  RIKEN.Sust-4    0.844725
# 2713   RIKEN.Sust-14  RIKEN.Sust-2    0.844050
# 2724   RIKEN.Sust-14  RIKEN.Sust-4    0.842980
#
# [100 rows x 3 columns]

# %%
# # prompt: Using dataframe similarity_df: Replace the values of columns Source and Target with the corresponding "cluster" in the `dms` data frame. Use the column "label" in `dms` to find the matches.

# # Assuming you have a dataframe named 'dms' with 'label' and 'cluster' columns

# # Create a dictionary mapping 'label' to 'cluster' from the 'dms' dataframe
# label_to_cluster = dict(zip(dms['label'], dms['cluster']))

# # Replace 'Source' column values with corresponding 'cluster' values
# similarity_df['Source'] = similarity_df['Source'].map(label_to_cluster)

# # Replace 'Target' column values with corresponding 'cluster' values
# similarity_df['Target'] = similarity_df['Target'].map(label_to_cluster)

# similarity_df.head()

# %%
similarity_df.to_csv(f'{ROOT_FOLDER_PATH}/{heatmap_settings["metadata"]["heatmap_analysis_id"]}/heatmap_melted.csv', index = False)
