# %% [markdown]
# # Compute Embeddings for Topic Modeling
#
# This notebook computes sentence embeddings from a bibliometric dataset using a transformer model (e.g. `all-MiniLM-L6-v2`).
#
# **What it does:**
# 1. Reads configuration from `config_dataset.yml`
# 2. Loads the cleaned dataset CSV
# 3. Concatenates text columns, applies optional cleaning
# 4. Computes embeddings with `SentenceTransformer`
# 5. Saves embeddings as `.npy` and the corpus as `.csv`
#
# **Prerequisites:**
# - `config_dataset.yml` must be configured (see `embeds` section)
# - The dataset must already exist (run `a00_data_loader.R` first)
# - Python environment with packages in `requirements_embeds.txt`

# %% [markdown]
# ## Setup

# %%
import os
import re
import json
import yaml
import numpy as np
import pandas as pd
from pathlib import Path
from sentence_transformers import SentenceTransformer

# %%
# Load configuration from YAML
with open("config_dataset.yml", "r") as f:
    config = yaml.safe_load(f)

meta = config["metadata"]
embeds_config = config["embeds"]

# Resolve paths
root_folder = Path(meta["bibliometrics_directory"])
project_folder = root_folder / meta["project_folder"]
filtered_folder = embeds_config["from_filtered_dataset"]

# Get the first embedding profile (e.g. "e01")
embed_key = next(k for k in embeds_config if k.startswith("e"))
es = embeds_config[embed_key]

print(f"Project:    {meta['project_folder']}")
print(f"Filter:     {filtered_folder}")
print(f"Embed key:  {embed_key}")
print(f"Model:      {es['transformer_model']}")
print(f"Columns:    {es['text_columns']}")
# Out:
# Project:    Q346_hydrogen_d3
# Filter:     f01
# Embed key:  e01
# Model:      all-MiniLM-L6-v2
# Columns:    ['TI', 'AB']

# %%
## Load and Prepare Data

# %%
# Load dataset
dataset_path = project_folder / filtered_folder / "dataset_raw_cleaned.csv"
df_full = pd.read_csv(dataset_path, encoding="latin-1")
print(f"Dataset: {df_full.shape[0]} rows x {df_full.shape[1]} columns")
df_full.head()
# Out:
# Dataset: 39031 rows x 42 columns
#    X_N                                  uuid PT  \
# 0    1  c556c198-adf6-412f-b8c2-2d631d9cfcf4  J
# 1    2  4d496213-6614-4ee5-b688-6a1a3837ec04  J
# 2    3  1a2b9d85-e3fc-4996-9f60-e4aa08a52512  J
# 3    4  c440c8f5-285d-4cd0-8aaa-65b6f2480f17  S
# 4    5  2e520747-341a-41de-b679-6a8950d2e12f  J
#
#                                                   AU  \
# 0                 DUGMORE, GM; POWELS, GJ; ZEELIE, B
# 1     FINKBEINER, M; NEEB, P; HORIE, O; MOORTGAT, GK
# 2  Kufeld, KA; Wonderly, WR; Paulson, LO; Kettwic...
# 3                          Shimbayashi, T; Fujita, K
# 4  Contreras-Diaz, C; Naharro-Ovejero, V; Araya-L...
#
#                                                   AF  \
# 0                 DUGMORE, GM; POWELS, GJ; ZEELIE, B
# 1     FINKBEINER, M; NEEB, P; HORIE, O; MOORTGAT, GK
# 2  Kufeld, Kylie A.; Wonderly, William R.; Paulso...
# 3              Shimbayashi, Takuya; Fujita, Ken-ichi
# ...

# %%
text_columns = es["text_columns"]
id_column = es.get("id_column", ["UT"])[0] if isinstance(es.get("id_column"), list) else es.get("id_column", "UT")

# Ensure text columns are strings, then concatenate
for col in text_columns:
    df_full[col] = df_full[col].astype(str)
df_full["text"] = df_full[text_columns].apply(" ".join, axis=1)

# Clean: remove non-alphabetic characters, strip "nan" artifacts
df_full["text"] = (
    df_full["text"]
    .apply(lambda x: re.sub(r"[^a-zA-Z\s]", "", x))
    .str.replace("nan ", "", regex=False)
    .str.strip()
)

# Optional transformations from config
if es.get("to_lowercase", False):
    df_full["text"] = df_full["text"].str.lower()

# Build corpus with just the columns needed (avoid duplicate column names)
corpus_columns = list(dict.fromkeys(["text", "UT", id_column]))
df_corpus = df_full[corpus_columns].dropna().reset_index(drop=True)
print(f"Corpus: {len(df_corpus)} documents")
df_corpus.head()
# Out:
# Corpus: 39031 documents
#                                                 text                   UT
# 0  MECHANISTIC ASPECTS OF BENZYLIC BROMIDE FORMAT...  WOS:A1995RF89100001
# 1  A METHOD OF CALIBRATION OF THE FORMICACID MONO...  WOS:A1995RH36200008
# 2  Transient HO Infrared Satellite Peaks Produced...  WOS:000299860200013
# 3  IridiumCatalyzed Dehydrogenative Reactions Thi...  WOS:000686138000002
# 4  Selective VaporPhase Formic Acid Decomposition...  WOS:001575900300001

# %%
# Create output folder and save corpus
embeds_folder = project_folder / filtered_folder / embed_key
embeds_folder.mkdir(parents=True, exist_ok=True)

df_corpus.to_csv(embeds_folder / "corpus.csv", index=False)
print(f"Output: {embeds_folder}")
# Out:
# Output: /Users/cristian/Library/CloudStorage/GoogleDrive-cristianmejia00@gmail.com/My Drive/Bibliometrics_Drive/Q346_hydrogen_d3/f01/e01

# %% [markdown]
# ## Compute and Save Embeddings

# %%
# Compute embeddings
model = SentenceTransformer(es["transformer_model"])
docs = df_corpus["text"].tolist()
embeddings = model.encode(docs, show_progress_bar=True)
print(f"Embeddings shape: {embeddings.shape}")
# Out:
# Batches: 100%|██████████| 1220/1220 [04:10<00:00,  4.87it/s]
# Embeddings shape: (39031, 384)

# %%
# Save embeddings as numpy (.npy) and IDs as JSON
np.save(embeds_folder / "embeddings.npy", embeddings)

id_values = df_corpus.loc[:, id_column]
if isinstance(id_values, pd.DataFrame):
    id_values = id_values.iloc[:, 0]
ids = id_values.astype(str).tolist()

with open(embeds_folder / "embeddings_ids.json", "w") as f:
    json.dump(ids, f)

print(f"Saved: embeddings.npy ({embeddings.shape})")
print(f"Saved: embeddings_ids.json ({len(ids)} IDs)")
# Out:
# Saved: embeddings.npy ((39031, 384))
# Saved: embeddings_ids.json (39031 IDs)

# %%
# Save a snapshot of the embeds config used
with open(embeds_folder / "embeds_settings.json", "w") as f:
    json.dump(es, f, indent=2)

print("Done.")
